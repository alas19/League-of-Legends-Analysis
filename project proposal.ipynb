# %% [markdown]
# # League of Legends Analysis for 51,490 Played Game
# ## Leyla Alas 090190739

# %% [markdown]
#    I am a *Lol player* since I graduated from highschool. Back then, I did not know all this kind of stuffs. Now, I will use a dataset about League of Legends from 9th season and all the game played in Europe server. Actually, I was looking for a Covid-19 dataset on [Github](https://github.com/topics/dataset). After that, I found this [Github repository](https://github.com/leomaurodesenv/game-datasets) by chance and I decided to look at it. Then, I went [through](https://www.kaggle.com/datasets/datasnaek/league-of-legends?select=games.csv) [these](https://www.kaggle.com/code/youngprize33/py-pandas-tutorial) [pages](https://www.datamanim.com/dataset/99_pandas/pandasMain.html) (each of them has different links). Finally, Here is [my dataset](https://raw.githubusercontent.com/Datamanim/pandas/main/lol.csv).

# %%
import pandas as pd
from urllib.request import urlopen
from collections import Counter

# %%
with urlopen('https://raw.githubusercontent.com/Datamanim/pandas/main/lol.csv') as url:
    data = pd.read_csv(url, sep = '\t')

# %% [markdown]
# + I am already interested in games especially *Riot Games* games. I am using this Lol data for looking at the win rates for each played characters and banned characters. Some of the things we see in the columns of the dataset are effective in winning this game like rift herald, baron, dragon kills.
# + I will observe how effective the selected characters, banned characters, received objectives are on the winning rate. I will also investigate how long an average game lasts, if it has an effect, how much the factors I have mentioned affect it. I will also examine the winning and losing rates of the characters played against each other. Later I will apply them in my own games.

# %% [markdown]
# ### Project Stages
# + Firstly, I have to read json typed dataset in this [link](https://www.kaggle.com/datasets/datasnaek/league-of-legends?select=games.csv) because, I will use them with my main dataset. In the json datasets, there are information about League of Legends charachters.
# + About this dataset, there are several terms about the game, so not everyone may know. I will explain some terms.
# + I will seperate teams as its real name not 1 or 2, blue and red and replace charachter codes to charachter names.
# + Then, I will do some data acquisition to reach every purpose of the project. I said that the character selected in the game affects the result. I will analyze it on a character basis. I will also calculate a win rate on the basis of banned characters. I will investigate if the objectives on the lol map lead the teams to win.
# + With this project, I will actually make more inferences on the basis of characters. Later on, I will explain the results that I can apply to my own game.

# %%
data_winner = data[ 'winner']
data_winner = data_winner.replace([0,1,2],['neither','blue','red'])
Counter(data_winner)
# Out:
# Counter({'blue': 26077, 'red': 25413})

# %% [markdown]
#     Here is an example for rename teams.

# %% [markdown]
# ## Requirements
# + The **pandas library**, which we use the most due to the content of our course, will allow us to operate on datasets.
# + I will use the **json library** to read the json dataset.
# + **Numpy library** is for linear algebra.
# + For statistical data visualization, I will use **seaborn library** and generally visualize the data I will use **matplotlib.pyplot library**.

# %% [markdown]
# ## Timing
#
# I will do this project as soon as possible because the subject is my favorite leisure. Even if I do not have time, I play. There is problem to have json datasets since I do not have their url's. I guess, It will take some time. Other processes will not take much time as I can easily find it by doing research on the internet or I already know.
